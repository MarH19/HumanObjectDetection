# %%
import pandas as pd
def evaluation(path):
    df = pd.read_csv(path,usecols=["Time_sec"])#,"Time_nsec","prediction_duration","contact_out","collision_out"])
    print(df.head(1))
    print(df.shape)

# %%
import os

# Get the absolute path of the current working directory
current_directory = os.path.abspath("")

for filename in os.listdir(current_directory):
    if filename != "Evaluation.ipynb" and filename =="test_left_offset_model_hard":
        filepath = os.path.join(current_directory, filename)
        path = filepath + r"\model_result.csv"
        evaluation(path)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
